# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/sharo/Downloads/Stores (1).csv")
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
rng=df['Store_Sales'].max()-df['Store_Sales'].min()
rng
# Out:
# 101400

# %%
x=df["Store_Sales"]
mean=df["Store_Sales"].mean()
std=df["Store_Sales"].std()
z=(x-mean)/std
z
# Out:
# 0      0.415264
# 1     -1.136153
# 2     -0.310708
# 3     -0.326996
# 4     -0.740591
#          ...
# 891    0.409447
# 892    1.322147
# 893    0.994064
# 894    2.167370
# 895   -0.291512
# Name: Store_Sales, Length: 896, dtype: float64

# %%
df["z-score"]=z

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales  \
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620
#
#     z-score
# 0  0.415264
# 1 -1.136153
# 2 -0.310708
# 3 -0.326996
# 4 -0.740591

# %%
ax=plt.figure(figsize=(10,6))
sns.distplot(df['z-score'],color="blue")
# Out:
# C:\Users\sharo\AppData\Local\Temp\ipykernel_1536\2571602486.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['z-score'],color="blue")
# <Axes: xlabel='z-score', ylabel='Density'>

# %%
out1=df[df["z-score"]>3]
out1
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 649        650        1989             2414                   860
#
#      Store_Sales   z-score
# 649       116320  3.313917

# %%
sns.pairplot(df,palette='paired')
# Out:
# C:\Users\sharo\New folder\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\sharo\New folder\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\sharo\New folder\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\sharo\New folder\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\sharo\New folder\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# ...

# %%
ax=plt.figure(figsize=(10,6))
sns.distplot(df["Items_Available"],color="green",bins=100)
# Out:
# C:\Users\sharo\AppData\Local\Temp\ipykernel_1536\952373651.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Items_Available"],color="green",bins=100)
# <Axes: xlabel='Items_Available', ylabel='Density'>

# %%
ax=plt.figure(figsize=(10,6))
sns.scatterplot(x='Store_Area',y='Items_Available',data=df,color="blue")
# Out:
# <Axes: xlabel='Store_Area', ylabel='Items_Available'>

# %%
ax=plt.figure(figsize=(10,6))
sns.scatterplot(x='Store_Sales',y='Items_Available',data=df,color="blue")
# Out:
# <Axes: xlabel='Store_Sales', ylabel='Items_Available'>

# %%
ax=plt.figure(figsize=(10,6))
sns.scatterplot(x='Store_Sales',y='Store_Area',data=df,color="blue")
# Out:
# <Axes: xlabel='Store_Sales', ylabel='Store_Area'>

# %%
ax=plt.figure(figsize=(10,6))
sns.scatterplot(x='Store_Sales',y='Daily_Customer_Count',data=df,color="blue")
# Out:
# <Axes: xlabel='Store_Sales', ylabel='Daily_Customer_Count'>

# %%
ax=plt.figure(figsize=(10,6))
corr=df.corr()
sns.heatmap(corr,linewidths=1,linecolor='white',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Model1:

# %%
#Assigning the independent and dependent variables as x and y respectivelyT

# %%
x=df[["Daily_Customer_Count"]]
y=df[["Store_Sales"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
intercept=lr.intercept_
intercept
# Out:
# array([59900.61346603])

# %%
coef=lr.coef_[0]
coef
# Out:
# array([-0.92995614])

# %%
pred=lr.predict(x_test)

# %%
plt.plot(y_test,pred)

# %%
from sklearn.metrics import r2_score
r2=(r2_score(y_test,pred))
print(r2*100)
# Out:
# -0.6291680857297921

# %%
from sklearn.metrics import mean_absolute_error
error=mean_absolute_error(y_test,pred)
error
# Out:
# 13318.772007845078

# %%
#The above model has a high error making it a failed model

# %% [markdown]
# # Model 2:

# %%
x1=df[["Store_Area"]]
y1=df[["Items_Available"]]

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
lr1=LinearRegression()

# %%
lr1.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
intercept1=lr1.intercept_
intercept1
# Out:
# array([5.28213962])

# %%
coef1=lr1.coef_[0]
coef1
# Out:
# array([1.1960332])

# %%
pred1=lr1.predict(x1_test)

# %%
plt.plot(y1_test,pred1)

# %%
from sklearn.metrics import r2_score
r2_1=(r2_score(y1_test,pred1))
print(r2_1*100)
# Out:
# 99.75369279818469

# %%
#The model is able to explain 99% of the data

# %% [markdown]
# # Absolute error in the data

# %%
from sklearn.metrics import mean_absolute_error
error1=mean_absolute_error(y1_test,pred1)
error1
# Out:
# 11.944631101516523

# %%
#The data has low error

# %% [markdown]
# # Conclusion

# %%
# Model 2 is well explained and thus the model stands
# the Model is 99% explianed
# thus we find that an increase in store area leads to increase in items available and vice versa
